# %% [markdown]
# #### se importan paqueterias necesarias

# %%
import pandas as pd
import pandasql as ps
#from urllib.request import urlopen
#import urllib.request
#import requests
import time 
import numpy as np
import re
from selenium import webdriver
#from selenium.webdriver.common.keys import Keys

# %% [markdown]
# #### requeremientos

# %%
## instalacion de web driver 
## instalacion de selenium y pandas sql

# %% [markdown]
# #### definiciones

# %%
# tag html: Una etiqueta HTML es una pieza de lenguaje de marcado que se utiliza para indicar el principio y el final 
#           de un elemento HTML en un documento HTML. Como parte de un elemento HTML, las etiquetas HTML ayudan 
#           a los navegadores web a convertir documentos HTML en páginas web.


# class html: La clase es un atributo que especifica uno o más nombres de clase para un elemento HTML. El atributo de clase 
#             se puede utilizar en cualquier elemento HTML. CSS y JavaScript pueden usar el nombre de clase para realizar 
#             ciertas tareas para elementos con el nombre de clase especificado

# %%
aux=pd.DataFrame()

# %%
aux.to_excel("df_soriana.xlsx",index=False)

# %%
################

# %% [markdown]
# ### se hace el primer web scraper

# %%
def Buscador_Precios_Selenium_Soriana(producto):
    
    ### ingresamos a la pagina web 
    path ="C:\webdriver3\chromedriver.exe"
    #path= mipath
    driver=webdriver.Chrome(path)
    url= "https://www.soriana.com/buscar?q="+producto+"&cid=&search-button="
    driver.get(url)
    
    ####### Accedemos a los elementos que contienen los datos que queremos de la pagina web 
    

    productos= driver.find_elements_by_class_name("product")
    
    ### accedemos a las urls almacenadas en la variable productos

    lista_urls=list()
    for i in range(len(productos)):
        try:
            lista_urls.append(productos[i].find_element_by_tag_name("a").get_attribute("href"))
        except:
            lista_urls.append(np.nan)
            
    ### accedemos a los nombres de los productos

    lista_nombres=list()
    for i in range(len(productos)):
        try:
            lista_nombres.append(productos[i].find_elements_by_tag_name("a")[2].text)
        except:
            lista_nombres.append(np.nan)
            
            
    ### accedemos a los precios base y promo de los productos 

    lista_precios=list()
    lista_promos=list()
    for i in range(len(productos)):
        try:
            lista_precios.append(productos[i].find_elements_by_class_name("value")[0].text)
        except:
            lista_precios.append(np.nan)
        try:
            lista_promos.append(productos[i].find_elements_by_class_name("value")[1].text)
        except:
            lista_promos.append(np.nan)





    df_soriana =pd.DataFrame({"nombre":lista_nombres,"url":lista_urls,"precio1":lista_promos,"precio2":lista_precios})
    df_soriana["autoservicio"]="soriana"
    df_soriana["marca"]= producto
    df_soriana["fecha"]= time.strftime("%d/%m/%y")

    df_soriana = df_soriana[["fecha","autoservicio","marca","nombre","url","precio1","precio2"]]
    ## este filtro apenas se agrega

    #df_soriana = df_soriana[df_soriana['nombre'].astype(str).str.contains(r'\b{}\b'.format(producto), regex=True, case=False)]
    df_soriana  =df_soriana.reset_index(drop=True)



    datos_webscraper=pd.read_excel("df_soriana.xlsx")

    datos_webscraper= pd.concat([datos_webscraper,df_soriana],axis=0)

    datos_webscraper.to_excel("df_soriana.xlsx",index=False)

    driver.quit()
    return df_soriana

# %%
for productos in ["television","xbox","laptop"]:
    Buscador_Precios_Selenium_Soriana(productos)
    #Buscador_Precios_Selenium_Superama(productos)
    #Buscador_Precios_Selenium_Chedraui(productos)

# %%
df_soriana=pd.read_excel("df_soriana.xlsx")
df_soriana
# Out:
#        fecha autoservicio       marca  \
# 0   18/01/22      soriana  television
# 1   18/01/22      soriana  television
# 2   18/01/22      soriana  television
# 3   18/01/22      soriana  television
# 4   18/01/22      soriana  television
# 5   18/01/22      soriana  television
# 6   18/01/22      soriana  television
# 7   18/01/22      soriana  television
# 8   18/01/22      soriana  television
# 9   18/01/22      soriana  television
# 10  18/01/22      soriana  television
# 11  18/01/22      soriana  television
# 12  18/01/22      soriana  television
# 13  18/01/22      soriana  television
# 14  18/01/22      soriana  television
# 15  18/01/22      soriana        xbox
# 16  18/01/22      soriana        xbox
# 17  18/01/22      soriana        xbox
# 18  18/01/22      soriana        xbox
# 19  18/01/22      soriana        xbox
# 20  18/01/22      soriana        xbox
# 21  18/01/22      soriana        xbox
# 22  18/01/22      soriana        xbox
# 23  18/01/22      soriana        xbox
# 24  18/01/22      soriana        xbox
# 25  18/01/22      soriana        xbox
# 26  18/01/22      soriana        xbox
# 27  18/01/22      soriana        xbox
# 28  18/01/22      soriana        xbox
# 29  18/01/22      soriana        xbox
#
#                                                nombre  \
# 0   Pantalla Samsung 43 Pulg FHD LED Smart TV LH43...
# 1   Pantalla Samsung 65 Pulg 8K QLED Smart TV QN65...
# 2   Pantalla Samsung 65 Pulg 4K QLED Frame Smart T...
# 3   Pantalla Samsung 55 Pulg 4K QLED Frame Smart T...
# 4   Pantalla Samsung 50 Pulg 4K QLED Frame Smart T...
# 5   Pantalla Samsung 32 Pulg FHD QLED Frame Smart ...
# 6   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 7   Pantalla Samsung 32 Pulg HD LED Smart TV LH32B...
# 8         Pantalla LG 70 Pulg 4K AI ThinQ 70UN7370PUC
# 9   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 10    Pantalla LG 60 Pulg 4K LED AI ThinQ 60UN7300PUA
# 11    Pantalla LG 32 Pulg HD LED AI ThinQ 32LM630BPUB
# 12        Pantalla LG 75 Pulg 4K AI ThinQ 75UP7750PSB
# 13        Pantalla LG 65 Pulg 4K AI ThinQ 65UP7500PSF
# 14            Pantalla TCL 55 Pulg 4k UHD LED Roku TV
# 15             Consola Xbox Series S 512GB SSD Blanca
# 16  Audífonos Estéreo Xbox Edición Especial 20 Ani...
# 17                             Halo Infinite XBOX One
# 18       Kit Gamer DreamGEAR DGXB1-6631 para Xbox One
# 19  Audífonos Gamer DreamGEAR X-Talk DGXB1-6618 pa...
# 20  Audífonos Gamer DreamGEAR X-Talk DGXB1-6617 pa...
# 21  Halo Infinite Collector's Steelbook Edition XB...
# 22            Control Inalámbrico XBOX QAU-00031 Azul
# 23          Control Inalámbrico XBOX QAS-00011 Blanco
# 24           Control Inalámbrico XBOX QAT-00011 Negro
# 25           Audífonos Hyperx Cloud Stinger Core Xbox
# 26  Control Inalámbrico Blanco Xbox + Tarjeta Fort...
# 27             Control Xbox Inalámbrico Negro Para Pc
# 28                      Forza Horizon 5 XBOX Series X
# 29         Audífonos Dreamgear GRX-340 Verde para XB1
#
#                                                   url     precio1     precio2
# 0   https://www.soriana.com/pantalla-samsung-43-pu...   $8,990.00  $11,490.00
# 1   https://www.soriana.com/pantalla-samsung-65-pu...         NaN  $85,999.00
# 2   https://www.soriana.com/pantalla-samsung-65-pu...  $39,490.00  $64,999.00
# 3   https://www.soriana.com/pantalla-samsung-55-pu...  $27,990.00  $34,999.00
# 4   https://www.soriana.com/pantalla-samsung-50-pu...  $24,590.00  $41,599.00
# 5   https://www.soriana.com/pantalla-samsung-32-pu...         NaN  $19,399.00
# 6   https://www.soriana.com/pantalla-samsung-55-pu...  $17,590.00  $30,490.00
# 7   https://www.soriana.com/pantalla-samsung-32-pu...   $4,990.00   $6,999.00
# 8   https://www.soriana.com/pantalla-lg-70-pulg-4k...  $19,990.00  $38,790.00
# 9   https://www.soriana.com/pantalla-samsung-55-pu...  $19,990.00  $44,490.00
# 10  https://www.soriana.com/pantalla-lg-60-pulg-4k...  $15,990.00  $25,590.00
# 11  https://www.soriana.com/pantalla-lg-32-pulg-hd...   $6,490.00   $6,990.00
# 12  https://www.soriana.com/pantalla-lg-75-pulg-4k...  $24,990.00  $41,190.00
# 13  https://www.soriana.com/pantalla-lg-65-pulg-4k...  $13,990.00  $28,490.00
# 14  https://www.soriana.com/pantalla-tcl-55-pulg-4...   $9,990.00  $13,299.00
# 15  https://www.soriana.com/consola-xbox-series-s-...         NaN   $8,499.00
# 16  https://www.soriana.com/audifonos-estereo-xbox...         NaN   $1,799.00
# 17  https://www.soriana.com/halo-infinite-xbox-one...         NaN   $1,499.00
# 18  https://www.soriana.com/kit-gamer-dreamgear-dg...         NaN   $1,199.00
# 19  https://www.soriana.com/audifonos-gamer-dreamg...         NaN     $499.00
# 20  https://www.soriana.com/audifonos-gamer-dreamg...         NaN     $499.00
# 21  https://www.soriana.com/halo-infinite-collecto...         NaN   $1,499.00
# 22  https://www.soriana.com/control-inalambrico-xb...         NaN   $1,699.00
# 23  https://www.soriana.com/control-inalambrico-xb...         NaN   $1,599.00
# 24  https://www.soriana.com/control-inalambrico-xb...         NaN   $1,599.00
# 25  https://www.soriana.com/audifonos-hyperx-cloud...         NaN     $899.00
# 26  https://www.soriana.com/control-inalambrico-bl...         NaN   $1,619.00
# 27  https://www.soriana.com/control-xbox-inalambri...         NaN   $1,599.00
# 28  https://www.soriana.com/forza-horizon-5-xbox-s...         NaN   $1,499.00
# 29  https://www.soriana.com/audifonos-dreamgear-gr...         NaN     $799.00

# %%
def precios_floats(datos):

        
    #### eliminamos el signo de pesos de ambas columnas
    
    for i in range(len(datos["precio1"])):
        try:
            datos["precio1"].iloc[i]=datos["precio1"].iloc[i].strip("$")
        except:
            pass
        
    for i in range(len(datos["precio2"])):
        try:
            datos["precio2"].iloc[i]=datos["precio2"].iloc[i].strip("$")
        except:
            pass
        
    
    ### quitamos la separacion de comas para miles
    
    datos["precio1"]=datos["precio1"].replace(",","",regex=True)
    datos["precio2"]=datos["precio2"].replace(",","",regex=True)
    
     
        
    ### convertimos los precios a numericos    
    datos['precio1'] = pd.to_numeric(datos['precio1'], errors='coerce')
    datos['precio2'] = pd.to_numeric(datos['precio2'], errors='coerce')

    
    
    datos.to_excel("df_soriana_limpio.xlsx",index=False)
        
     ### visualizamos los tipos de datos
    print(datos.dtypes)
    return datos

# %%
precios_floats(df_soriana)
# Out:
# fecha            object
# autoservicio     object
# marca            object
# nombre           object
# url              object
# precio1         float64
# precio2         float64
# dtype: object
#        fecha autoservicio       marca  \
# 0   18/01/22      soriana  television
# 1   18/01/22      soriana  television
# 2   18/01/22      soriana  television
# 3   18/01/22      soriana  television
# 4   18/01/22      soriana  television
# 5   18/01/22      soriana  television
# 6   18/01/22      soriana  television
# 7   18/01/22      soriana  television
# 8   18/01/22      soriana  television
# 9   18/01/22      soriana  television
# 10  18/01/22      soriana  television
# 11  18/01/22      soriana  television
# 12  18/01/22      soriana  television
# 13  18/01/22      soriana  television
# 14  18/01/22      soriana  television
# 15  18/01/22      soriana        xbox
# 16  18/01/22      soriana        xbox
# 17  18/01/22      soriana        xbox
# 18  18/01/22      soriana        xbox
# 19  18/01/22      soriana        xbox
# 20  18/01/22      soriana        xbox
# 21  18/01/22      soriana        xbox
# 22  18/01/22      soriana        xbox
# 23  18/01/22      soriana        xbox
# 24  18/01/22      soriana        xbox
# 25  18/01/22      soriana        xbox
# 26  18/01/22      soriana        xbox
# 27  18/01/22      soriana        xbox
# 28  18/01/22      soriana        xbox
# 29  18/01/22      soriana        xbox
#
#                                                nombre  \
# 0   Pantalla Samsung 43 Pulg FHD LED Smart TV LH43...
# 1   Pantalla Samsung 65 Pulg 8K QLED Smart TV QN65...
# 2   Pantalla Samsung 65 Pulg 4K QLED Frame Smart T...
# 3   Pantalla Samsung 55 Pulg 4K QLED Frame Smart T...
# 4   Pantalla Samsung 50 Pulg 4K QLED Frame Smart T...
# 5   Pantalla Samsung 32 Pulg FHD QLED Frame Smart ...
# 6   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 7   Pantalla Samsung 32 Pulg HD LED Smart TV LH32B...
# 8         Pantalla LG 70 Pulg 4K AI ThinQ 70UN7370PUC
# 9   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 10    Pantalla LG 60 Pulg 4K LED AI ThinQ 60UN7300PUA
# 11    Pantalla LG 32 Pulg HD LED AI ThinQ 32LM630BPUB
# 12        Pantalla LG 75 Pulg 4K AI ThinQ 75UP7750PSB
# 13        Pantalla LG 65 Pulg 4K AI ThinQ 65UP7500PSF
# 14            Pantalla TCL 55 Pulg 4k UHD LED Roku TV
# 15             Consola Xbox Series S 512GB SSD Blanca
# 16  Audífonos Estéreo Xbox Edición Especial 20 Ani...
# 17                             Halo Infinite XBOX One
# 18       Kit Gamer DreamGEAR DGXB1-6631 para Xbox One
# 19  Audífonos Gamer DreamGEAR X-Talk DGXB1-6618 pa...
# 20  Audífonos Gamer DreamGEAR X-Talk DGXB1-6617 pa...
# 21  Halo Infinite Collector's Steelbook Edition XB...
# 22            Control Inalámbrico XBOX QAU-00031 Azul
# 23          Control Inalámbrico XBOX QAS-00011 Blanco
# 24           Control Inalámbrico XBOX QAT-00011 Negro
# 25           Audífonos Hyperx Cloud Stinger Core Xbox
# 26  Control Inalámbrico Blanco Xbox + Tarjeta Fort...
# 27             Control Xbox Inalámbrico Negro Para Pc
# 28                      Forza Horizon 5 XBOX Series X
# 29         Audífonos Dreamgear GRX-340 Verde para XB1
#
#                                                   url  precio1  precio2
# 0   https://www.soriana.com/pantalla-samsung-43-pu...   8990.0  11490.0
# 1   https://www.soriana.com/pantalla-samsung-65-pu...      NaN  85999.0
# 2   https://www.soriana.com/pantalla-samsung-65-pu...  39490.0  64999.0
# 3   https://www.soriana.com/pantalla-samsung-55-pu...  27990.0  34999.0
# 4   https://www.soriana.com/pantalla-samsung-50-pu...  24590.0  41599.0
# 5   https://www.soriana.com/pantalla-samsung-32-pu...      NaN  19399.0
# 6   https://www.soriana.com/pantalla-samsung-55-pu...  17590.0  30490.0
# 7   https://www.soriana.com/pantalla-samsung-32-pu...   4990.0   6999.0
# 8   https://www.soriana.com/pantalla-lg-70-pulg-4k...  19990.0  38790.0
# 9   https://www.soriana.com/pantalla-samsung-55-pu...  19990.0  44490.0
# 10  https://www.soriana.com/pantalla-lg-60-pulg-4k...  15990.0  25590.0
# 11  https://www.soriana.com/pantalla-lg-32-pulg-hd...   6490.0   6990.0
# 12  https://www.soriana.com/pantalla-lg-75-pulg-4k...  24990.0  41190.0
# 13  https://www.soriana.com/pantalla-lg-65-pulg-4k...  13990.0  28490.0
# 14  https://www.soriana.com/pantalla-tcl-55-pulg-4...   9990.0  13299.0
# 15  https://www.soriana.com/consola-xbox-series-s-...      NaN   8499.0
# 16  https://www.soriana.com/audifonos-estereo-xbox...      NaN   1799.0
# 17  https://www.soriana.com/halo-infinite-xbox-one...      NaN   1499.0
# 18  https://www.soriana.com/kit-gamer-dreamgear-dg...      NaN   1199.0
# 19  https://www.soriana.com/audifonos-gamer-dreamg...      NaN    499.0
# 20  https://www.soriana.com/audifonos-gamer-dreamg...      NaN    499.0
# 21  https://www.soriana.com/halo-infinite-collecto...      NaN   1499.0
# 22  https://www.soriana.com/control-inalambrico-xb...      NaN   1699.0
# 23  https://www.soriana.com/control-inalambrico-xb...      NaN   1599.0
# 24  https://www.soriana.com/control-inalambrico-xb...      NaN   1599.0
# 25  https://www.soriana.com/audifonos-hyperx-cloud...      NaN    899.0
# 26  https://www.soriana.com/control-inalambrico-bl...      NaN   1619.0
# 27  https://www.soriana.com/control-xbox-inalambri...      NaN   1599.0
# 28  https://www.soriana.com/forza-horizon-5-xbox-s...      NaN   1499.0
# 29  https://www.soriana.com/audifonos-dreamgear-gr...      NaN    799.0

# %%
df_soriana=pd.read_excel("df_soriana_limpio.xlsx")
df_soriana
# Out:
#        fecha autoservicio       marca  \
# 0   18/01/22      soriana  television
# 1   18/01/22      soriana  television
# 2   18/01/22      soriana  television
# 3   18/01/22      soriana  television
# 4   18/01/22      soriana  television
# 5   18/01/22      soriana  television
# 6   18/01/22      soriana  television
# 7   18/01/22      soriana  television
# 8   18/01/22      soriana  television
# 9   18/01/22      soriana  television
# 10  18/01/22      soriana  television
# 11  18/01/22      soriana  television
# 12  18/01/22      soriana  television
# 13  18/01/22      soriana  television
# 14  18/01/22      soriana  television
# 15  18/01/22      soriana        xbox
# 16  18/01/22      soriana        xbox
# 17  18/01/22      soriana        xbox
# 18  18/01/22      soriana        xbox
# 19  18/01/22      soriana        xbox
# 20  18/01/22      soriana        xbox
# 21  18/01/22      soriana        xbox
# 22  18/01/22      soriana        xbox
# 23  18/01/22      soriana        xbox
# 24  18/01/22      soriana        xbox
# 25  18/01/22      soriana        xbox
# 26  18/01/22      soriana        xbox
# 27  18/01/22      soriana        xbox
# 28  18/01/22      soriana        xbox
# 29  18/01/22      soriana        xbox
#
#                                                nombre  \
# 0   Pantalla Samsung 43 Pulg FHD LED Smart TV LH43...
# 1   Pantalla Samsung 65 Pulg 8K QLED Smart TV QN65...
# 2   Pantalla Samsung 65 Pulg 4K QLED Frame Smart T...
# 3   Pantalla Samsung 55 Pulg 4K QLED Frame Smart T...
# 4   Pantalla Samsung 50 Pulg 4K QLED Frame Smart T...
# 5   Pantalla Samsung 32 Pulg FHD QLED Frame Smart ...
# 6   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 7   Pantalla Samsung 32 Pulg HD LED Smart TV LH32B...
# 8         Pantalla LG 70 Pulg 4K AI ThinQ 70UN7370PUC
# 9   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 10    Pantalla LG 60 Pulg 4K LED AI ThinQ 60UN7300PUA
# 11    Pantalla LG 32 Pulg HD LED AI ThinQ 32LM630BPUB
# 12        Pantalla LG 75 Pulg 4K AI ThinQ 75UP7750PSB
# 13        Pantalla LG 65 Pulg 4K AI ThinQ 65UP7500PSF
# 14            Pantalla TCL 55 Pulg 4k UHD LED Roku TV
# 15             Consola Xbox Series S 512GB SSD Blanca
# 16  Audífonos Estéreo Xbox Edición Especial 20 Ani...
# 17                             Halo Infinite XBOX One
# 18       Kit Gamer DreamGEAR DGXB1-6631 para Xbox One
# 19  Audífonos Gamer DreamGEAR X-Talk DGXB1-6618 pa...
# 20  Audífonos Gamer DreamGEAR X-Talk DGXB1-6617 pa...
# 21  Halo Infinite Collector's Steelbook Edition XB...
# 22            Control Inalámbrico XBOX QAU-00031 Azul
# 23          Control Inalámbrico XBOX QAS-00011 Blanco
# 24           Control Inalámbrico XBOX QAT-00011 Negro
# 25           Audífonos Hyperx Cloud Stinger Core Xbox
# 26  Control Inalámbrico Blanco Xbox + Tarjeta Fort...
# 27             Control Xbox Inalámbrico Negro Para Pc
# 28                      Forza Horizon 5 XBOX Series X
# 29         Audífonos Dreamgear GRX-340 Verde para XB1
#
#                                                   url  precio1  precio2
# 0   https://www.soriana.com/pantalla-samsung-43-pu...   8990.0    11490
# 1   https://www.soriana.com/pantalla-samsung-65-pu...      NaN    85999
# 2   https://www.soriana.com/pantalla-samsung-65-pu...  39490.0    64999
# 3   https://www.soriana.com/pantalla-samsung-55-pu...  27990.0    34999
# 4   https://www.soriana.com/pantalla-samsung-50-pu...  24590.0    41599
# 5   https://www.soriana.com/pantalla-samsung-32-pu...      NaN    19399
# 6   https://www.soriana.com/pantalla-samsung-55-pu...  17590.0    30490
# 7   https://www.soriana.com/pantalla-samsung-32-pu...   4990.0     6999
# 8   https://www.soriana.com/pantalla-lg-70-pulg-4k...  19990.0    38790
# 9   https://www.soriana.com/pantalla-samsung-55-pu...  19990.0    44490
# 10  https://www.soriana.com/pantalla-lg-60-pulg-4k...  15990.0    25590
# 11  https://www.soriana.com/pantalla-lg-32-pulg-hd...   6490.0     6990
# 12  https://www.soriana.com/pantalla-lg-75-pulg-4k...  24990.0    41190
# 13  https://www.soriana.com/pantalla-lg-65-pulg-4k...  13990.0    28490
# 14  https://www.soriana.com/pantalla-tcl-55-pulg-4...   9990.0    13299
# 15  https://www.soriana.com/consola-xbox-series-s-...      NaN     8499
# 16  https://www.soriana.com/audifonos-estereo-xbox...      NaN     1799
# 17  https://www.soriana.com/halo-infinite-xbox-one...      NaN     1499
# 18  https://www.soriana.com/kit-gamer-dreamgear-dg...      NaN     1199
# 19  https://www.soriana.com/audifonos-gamer-dreamg...      NaN      499
# 20  https://www.soriana.com/audifonos-gamer-dreamg...      NaN      499
# 21  https://www.soriana.com/halo-infinite-collecto...      NaN     1499
# 22  https://www.soriana.com/control-inalambrico-xb...      NaN     1699
# 23  https://www.soriana.com/control-inalambrico-xb...      NaN     1599
# 24  https://www.soriana.com/control-inalambrico-xb...      NaN     1599
# 25  https://www.soriana.com/audifonos-hyperx-cloud...      NaN      899
# 26  https://www.soriana.com/control-inalambrico-bl...      NaN     1619
# 27  https://www.soriana.com/control-xbox-inalambri...      NaN     1599
# 28  https://www.soriana.com/forza-horizon-5-xbox-s...      NaN     1499
# 29  https://www.soriana.com/audifonos-dreamgear-gr...      NaN      799

# %%
ps.sqldf("select  * from df_soriana where (marca= 'xbox') limit 5")
# Out:
#       fecha autoservicio marca  \
# 0  18/01/22      soriana  xbox
# 1  18/01/22      soriana  xbox
# 2  18/01/22      soriana  xbox
# 3  18/01/22      soriana  xbox
# 4  18/01/22      soriana  xbox
#
#                                               nombre  \
# 0             Consola Xbox Series S 512GB SSD Blanca
# 1  Audífonos Estéreo Xbox Edición Especial 20 Ani...
# 2                             Halo Infinite XBOX One
# 3       Kit Gamer DreamGEAR DGXB1-6631 para Xbox One
# 4  Audífonos Gamer DreamGEAR X-Talk DGXB1-6618 pa...
#
#                                                  url precio1  precio2
# 0  https://www.soriana.com/consola-xbox-series-s-...    None     8499
# 1  https://www.soriana.com/audifonos-estereo-xbox...    None     1799
# 2  https://www.soriana.com/halo-infinite-xbox-one...    None     1499
# 3  https://www.soriana.com/kit-gamer-dreamgear-dg...    None     1199
# 4  https://www.soriana.com/audifonos-gamer-dreamg...    None      499

# %%
ps.sqldf("select count(*) from df_soriana where (marca= 'television') ")
# Out:
#    count(*)
# 0        15

# %%
ps.sqldf("select marca,avg(precio2) as preciopromedio from df_soriana group by marca ")
# Out:
#         marca  preciopromedio
# 0  television    32987.533333
# 1        xbox     1787.000000

# %%
ps.sqldf("select *  from df_soriana where precio1 is not null ")
# Out:
#        fecha autoservicio       marca  \
# 0   18/01/22      soriana  television
# 1   18/01/22      soriana  television
# 2   18/01/22      soriana  television
# 3   18/01/22      soriana  television
# 4   18/01/22      soriana  television
# 5   18/01/22      soriana  television
# 6   18/01/22      soriana  television
# 7   18/01/22      soriana  television
# 8   18/01/22      soriana  television
# 9   18/01/22      soriana  television
# 10  18/01/22      soriana  television
# 11  18/01/22      soriana  television
# 12  18/01/22      soriana  television
#
#                                                nombre  \
# 0   Pantalla Samsung 43 Pulg FHD LED Smart TV LH43...
# 1   Pantalla Samsung 65 Pulg 4K QLED Frame Smart T...
# 2   Pantalla Samsung 55 Pulg 4K QLED Frame Smart T...
# 3   Pantalla Samsung 50 Pulg 4K QLED Frame Smart T...
# 4   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 5   Pantalla Samsung 32 Pulg HD LED Smart TV LH32B...
# 6         Pantalla LG 70 Pulg 4K AI ThinQ 70UN7370PUC
# 7   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 8     Pantalla LG 60 Pulg 4K LED AI ThinQ 60UN7300PUA
# 9     Pantalla LG 32 Pulg HD LED AI ThinQ 32LM630BPUB
# 10        Pantalla LG 75 Pulg 4K AI ThinQ 75UP7750PSB
# 11        Pantalla LG 65 Pulg 4K AI ThinQ 65UP7500PSF
# 12            Pantalla TCL 55 Pulg 4k UHD LED Roku TV
#
#                                                   url     precio1     precio2
# 0   https://www.soriana.com/pantalla-samsung-43-pu...   $8,990.00  $11,490.00
# 1   https://www.soriana.com/pantalla-samsung-65-pu...  $39,490.00  $64,999.00
# 2   https://www.soriana.com/pantalla-samsung-55-pu...  $27,990.00  $34,999.00
# 3   https://www.soriana.com/pantalla-samsung-50-pu...  $24,590.00  $41,599.00
# 4   https://www.soriana.com/pantalla-samsung-55-pu...  $17,590.00  $30,490.00
# 5   https://www.soriana.com/pantalla-samsung-32-pu...   $4,990.00   $6,999.00
# 6   https://www.soriana.com/pantalla-lg-70-pulg-4k...  $19,990.00  $38,790.00
# 7   https://www.soriana.com/pantalla-samsung-55-pu...  $19,990.00  $44,490.00
# 8   https://www.soriana.com/pantalla-lg-60-pulg-4k...  $15,990.00  $25,590.00
# 9   https://www.soriana.com/pantalla-lg-32-pulg-hd...   $6,490.00   $6,990.00
# 10  https://www.soriana.com/pantalla-lg-75-pulg-4k...  $24,990.00  $41,190.00
# 11  https://www.soriana.com/pantalla-lg-65-pulg-4k...  $13,990.00  $28,490.00
# 12  https://www.soriana.com/pantalla-tcl-55-pulg-4...   $9,990.00  $13,299.00

# %%
ps.sqldf("select *  from df_soriana where precio1 <10000 or precio2<10000 ")
# Out:
#        fecha autoservicio       marca  \
# 0   18/01/22      soriana  television
# 1   18/01/22      soriana  television
# 2   18/01/22      soriana  television
# 3   18/01/22      soriana  television
# 4   18/01/22      soriana        xbox
# 5   18/01/22      soriana        xbox
# 6   18/01/22      soriana        xbox
# 7   18/01/22      soriana        xbox
# 8   18/01/22      soriana        xbox
# 9   18/01/22      soriana        xbox
# 10  18/01/22      soriana        xbox
# 11  18/01/22      soriana        xbox
# 12  18/01/22      soriana        xbox
# 13  18/01/22      soriana        xbox
# 14  18/01/22      soriana        xbox
# 15  18/01/22      soriana        xbox
# 16  18/01/22      soriana        xbox
# 17  18/01/22      soriana        xbox
# 18  18/01/22      soriana        xbox
#
#                                                nombre  \
# 0   Pantalla Samsung 43 Pulg FHD LED Smart TV LH43...
# 1   Pantalla Samsung 32 Pulg HD LED Smart TV LH32B...
# 2     Pantalla LG 32 Pulg HD LED AI ThinQ 32LM630BPUB
# 3             Pantalla TCL 55 Pulg 4k UHD LED Roku TV
# 4              Consola Xbox Series S 512GB SSD Blanca
# 5   Audífonos Estéreo Xbox Edición Especial 20 Ani...
# 6                              Halo Infinite XBOX One
# 7        Kit Gamer DreamGEAR DGXB1-6631 para Xbox One
# 8   Audífonos Gamer DreamGEAR X-Talk DGXB1-6618 pa...
# 9   Audífonos Gamer DreamGEAR X-Talk DGXB1-6617 pa...
# 10  Halo Infinite Collector's Steelbook Edition XB...
# 11            Control Inalámbrico XBOX QAU-00031 Azul
# 12          Control Inalámbrico XBOX QAS-00011 Blanco
# 13           Control Inalámbrico XBOX QAT-00011 Negro
# 14           Audífonos Hyperx Cloud Stinger Core Xbox
# 15  Control Inalámbrico Blanco Xbox + Tarjeta Fort...
# 16             Control Xbox Inalámbrico Negro Para Pc
# 17                      Forza Horizon 5 XBOX Series X
# 18         Audífonos Dreamgear GRX-340 Verde para XB1
#
#                                                   url  precio1  precio2
# 0   https://www.soriana.com/pantalla-samsung-43-pu...   8990.0    11490
# 1   https://www.soriana.com/pantalla-samsung-32-pu...   4990.0     6999
# 2   https://www.soriana.com/pantalla-lg-32-pulg-hd...   6490.0     6990
# 3   https://www.soriana.com/pantalla-tcl-55-pulg-4...   9990.0    13299
# 4   https://www.soriana.com/consola-xbox-series-s-...      NaN     8499
# 5   https://www.soriana.com/audifonos-estereo-xbox...      NaN     1799
# 6   https://www.soriana.com/halo-infinite-xbox-one...      NaN     1499
# 7   https://www.soriana.com/kit-gamer-dreamgear-dg...      NaN     1199
# 8   https://www.soriana.com/audifonos-gamer-dreamg...      NaN      499
# 9   https://www.soriana.com/audifonos-gamer-dreamg...      NaN      499
# 10  https://www.soriana.com/halo-infinite-collecto...      NaN     1499
# 11  https://www.soriana.com/control-inalambrico-xb...      NaN     1699
# 12  https://www.soriana.com/control-inalambrico-xb...      NaN     1599
# 13  https://www.soriana.com/control-inalambrico-xb...      NaN     1599
# 14  https://www.soriana.com/audifonos-hyperx-cloud...      NaN      899
# 15  https://www.soriana.com/control-inalambrico-bl...      NaN     1619
# 16  https://www.soriana.com/control-xbox-inalambri...      NaN     1599
# 17  https://www.soriana.com/forza-horizon-5-xbox-s...      NaN     1499
# 18  https://www.soriana.com/audifonos-dreamgear-gr...      NaN      799
