# %% [markdown]
# #### se importan paqueterias necesarias

# %%
import pandas as pd
import pandasql as ps
#from urllib.request import urlopen
#import urllib.request
#import requests
import time 
import numpy as np
import re
from selenium import webdriver
#from selenium.webdriver.common.keys import Keys

# %% [markdown]
# #### requeremientos

# %%
## instalacion de web driver 
## instalacion de selenium y pandas sql

# %% [markdown]
# #### definiciones

# %%
# tag html: Una etiqueta HTML es una pieza de lenguaje de marcado que se utiliza para indicar el principio y el final 
#           de un elemento HTML en un documento HTML. Como parte de un elemento HTML, las etiquetas HTML ayudan 
#           a los navegadores web a convertir documentos HTML en páginas web.


# class html: La clase es un atributo que especifica uno o más nombres de clase para un elemento HTML. El atributo de clase 
#             se puede utilizar en cualquier elemento HTML. CSS y JavaScript pueden usar el nombre de clase para realizar 
#             ciertas tareas para elementos con el nombre de clase especificado

# %%
aux=pd.DataFrame()

# %%
aux.to_excel("df_soriana.xlsx",index=False)

# %%
################

# %% [markdown]
# ### se hace el primer web scraper

# %%
def Buscador_Precios_Selenium_Soriana(producto):
    
    ### ingresamos a la pagina web 
    #path ="C:\webdriver3\chromedriver.exe"
    path = r"C:\Users\rtorr\OneDrive\Escritorio\TAREA_WEB_SCRAPING\chromedriver.exe"
    #path= mipath
    driver=webdriver.Chrome(path)
    url= "https://www.soriana.com/buscar?q="+producto+"&cid=&search-button="
    driver.get(url)
    
    ####### Accedemos a los elementos que contienen los datos que queremos de la pagina web 
    

    productos= driver.find_elements_by_class_name("product")
    
    ### accedemos a las urls almacenadas en la variable productos

    lista_urls=list()
    for i in range(len(productos)):
        try:
            lista_urls.append(productos[i].find_element_by_tag_name("a").get_attribute("href"))
        except:
            lista_urls.append(np.nan)
            
    ### accedemos a los nombres de los productos

    lista_nombres=list()
    for i in range(len(productos)):
        try:
            lista_nombres.append(productos[i].find_elements_by_tag_name("a")[2].text)
        except:
            lista_nombres.append(np.nan)
            
            
    ### accedemos a los precios base y promo de los productos 

    lista_precios=list()
    lista_promos=list()
    for i in range(len(productos)):
        try:
            lista_precios.append(productos[i].find_elements_by_class_name("value")[0].text)
        except:
            lista_precios.append(np.nan)
        try:
            lista_promos.append(productos[i].find_elements_by_class_name("value")[1].text)
        except:
            lista_promos.append(np.nan)





    df_soriana =pd.DataFrame({"nombre":lista_nombres,"url":lista_urls,"precio1":lista_promos,"precio2":lista_precios})
    df_soriana["autoservicio"]="soriana"
    df_soriana["marca"]= producto
    df_soriana["fecha"]= time.strftime("%d/%m/%y")

    df_soriana = df_soriana[["fecha","autoservicio","marca","nombre","url","precio1","precio2"]]
    ## este filtro apenas se agrega

    #df_soriana = df_soriana[df_soriana['nombre'].astype(str).str.contains(r'\b{}\b'.format(producto), regex=True, case=False)]
    df_soriana  =df_soriana.reset_index(drop=True)



    datos_webscraper=pd.read_excel("df_soriana.xlsx")

    datos_webscraper= pd.concat([datos_webscraper,df_soriana],axis=0)

    datos_webscraper.to_excel("df_soriana.xlsx",index=False)

    driver.quit()
    return df_soriana

# %%
for productos in ["television","xbox","laptop"]:
    Buscador_Precios_Selenium_Soriana(productos)
    #Buscador_Precios_Selenium_Superama(productos)
    #Buscador_Precios_Selenium_Chedraui(productos)
# Out:
# <ipython-input-10-e3dc1ebe4d8c>:7: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(path)
# <ipython-input-10-e3dc1ebe4d8c>:14: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   productos= driver.find_elements_by_class_name("product")
# C:\Users\rtorr\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:341: UserWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   warnings.warn("find_element_by_* commands are deprecated. Please use find_element() instead")
# C:\Users\rtorr\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:359: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")
# C:\Users\rtorr\anaconda3\lib\site-packages\selenium\webdriver\remote\webelement.py:464: UserWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   warnings.warn("find_elements_by_* commands are deprecated. Please use find_elements() instead")

# %%
df_soriana=pd.read_excel("df_soriana.xlsx")
df_soriana
# Out:
#        fecha autoservicio       marca  \
# 0   20/01/22      soriana  television
# 1   20/01/22      soriana  television
# 2   20/01/22      soriana  television
# 3   20/01/22      soriana  television
# 4   20/01/22      soriana  television
# 5   20/01/22      soriana  television
# 6   20/01/22      soriana  television
# 7   20/01/22      soriana  television
# 8   20/01/22      soriana  television
# 9   20/01/22      soriana  television
# 10  20/01/22      soriana  television
# 11  20/01/22      soriana  television
# 12  20/01/22      soriana  television
# 13  20/01/22      soriana  television
# 14  20/01/22      soriana  television
# 15  20/01/22      soriana        xbox
# 16  20/01/22      soriana        xbox
# 17  20/01/22      soriana        xbox
# 18  20/01/22      soriana        xbox
# 19  20/01/22      soriana        xbox
# 20  20/01/22      soriana        xbox
# 21  20/01/22      soriana        xbox
# 22  20/01/22      soriana        xbox
# 23  20/01/22      soriana        xbox
# 24  20/01/22      soriana        xbox
# 25  20/01/22      soriana        xbox
# 26  20/01/22      soriana        xbox
# 27  20/01/22      soriana        xbox
# 28  20/01/22      soriana        xbox
# 29  20/01/22      soriana        xbox
# 30  20/01/22      soriana      laptop
# 31  20/01/22      soriana      laptop
# 32  20/01/22      soriana      laptop
# 33  20/01/22      soriana      laptop
# 34  20/01/22      soriana      laptop
# 35  20/01/22      soriana      laptop
# 36  20/01/22      soriana      laptop
# 37  20/01/22      soriana      laptop
# 38  20/01/22      soriana      laptop
# 39  20/01/22      soriana      laptop
# 40  20/01/22      soriana      laptop
# 41  20/01/22      soriana      laptop
# 42  20/01/22      soriana      laptop
# 43  20/01/22      soriana      laptop
# 44  20/01/22      soriana      laptop
#
#                                                nombre  \
# 0   Pantalla Samsung 43 Pulg FHD LED Smart TV LH43...
# 1   Pantalla Samsung 65 Pulg 8K QLED Smart TV QN65...
# 2   Pantalla Samsung 65 Pulg 4K QLED Frame Smart T...
# 3   Pantalla Samsung 55 Pulg 4K QLED Frame Smart T...
# 4   Pantalla Samsung 50 Pulg 4K QLED Frame Smart T...
# 5   Pantalla Samsung 32 Pulg FHD QLED Frame Smart ...
# 6   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 7         Pantalla LG 70 Pulg 4K AI ThinQ 70UN7370PUC
# 8     Pantalla LG 60 Pulg 4K LED AI ThinQ 60UN7300PUA
# 9     Pantalla LG 32 Pulg HD LED AI ThinQ 32LM630BPUB
# 10        Pantalla LG 75 Pulg 4K AI ThinQ 75UP7750PSB
# 11            Pantalla TCL 55 Pulg 4k UHD LED Roku TV
# 12            Pantalla TCL 50 Pulg 4k UHD LED Roku TV
# 13  Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 14             Pantalla Samsung 24 Pulg LT24D315NQ/ZX
# 15             Consola Xbox Series S 512GB SSD Blanca
# 16                             Halo Infinite XBOX One
# 17       Kit Gamer DreamGEAR DGXB1-6631 para Xbox One
# 18  Audífonos Gamer DreamGEAR X-Talk DGXB1-6618 pa...
# 19  Audífonos Gamer DreamGEAR X-Talk DGXB1-6617 pa...
# 20  Halo Infinite Collector's Steelbook Edition XB...
# 21  Audífonos Estéreo Xbox Edición Especial 20 Ani...
# 22          Control Inalámbrico XBOX QAS-00011 Blanco
# 23           Control Inalámbrico XBOX QAT-00011 Negro
# 24           Audífonos Hyperx Cloud Stinger Core Xbox
# 25  Control Inalámbrico Blanco Xbox + Tarjeta Fort...
# 26             Control Xbox Inalámbrico Negro Para Pc
# 27                      Forza Horizon 5 XBOX Series X
# 28            Control Inalámbrico XBOX QAU-00031 Azul
# 29         Audífonos Dreamgear GRX-340 Verde para XB1
# 30             Laptop HP 13-bb0501la Ci3 8GB/256GBSSD
# 31  Laptop Asus C204EE-Cel4G32COs-01 Celeron N4020...
# 32  Laptop Asus BDL C436FA-I38G12 Core i3 8GB RAM ...
# 33  Laptop HP 28K53LT ABM AMD Athlon Silver 4GB RA...
# 34  Laptop HP 14-dk1010la AMD Athlon 4GB RAM 500GB...
# 35  Laptop HP 14 DY0005LA Intel Core i3 8 GB RAM 2...
# 36  Laptop Asus F545FA-I58G1TWH-0 Core i5 8GB RAM ...
# 37  Laptop HP 15-DY1002LA Core i3 8GB RAM 256GB SS...
# 38  Laptop Asus P1440FA-FQ1592R Core i3 8GB RAM 25...
# 39  Laptop HP OMEN 15-EK0007LA Core i7 16GB RAM 51...
# 40  Computadora Ghia 2888 Squadra AIO Celeron N345...
# 41  Computadora Asus D540SA-I34G1TWP-0 Core i3 4GB...
# 42  Computadora Asus D641SC-I38G1TWP-0 Core i3 8GB...
# 43  Mini PC Ghia PCGHIA-2122 Celeron 4GB RAM 64GB ...
# 44  Computadora HP All In One Pavilion 24-K0001LA ...
#
#                                                   url     precio1     precio2
# 0   https://www.soriana.com/pantalla-samsung-43-pu...   $8,990.00  $11,490.00
# 1   https://www.soriana.com/pantalla-samsung-65-pu...         NaN  $85,999.00
# 2   https://www.soriana.com/pantalla-samsung-65-pu...  $39,490.00  $64,999.00
# 3   https://www.soriana.com/pantalla-samsung-55-pu...  $27,990.00  $34,999.00
# 4   https://www.soriana.com/pantalla-samsung-50-pu...  $24,590.00  $41,599.00
# 5   https://www.soriana.com/pantalla-samsung-32-pu...         NaN  $19,399.00
# 6   https://www.soriana.com/pantalla-samsung-55-pu...  $17,590.00  $30,490.00
# 7   https://www.soriana.com/pantalla-lg-70-pulg-4k...  $19,990.00  $38,790.00
# 8   https://www.soriana.com/pantalla-lg-60-pulg-4k...  $15,990.00  $25,590.00
# 9   https://www.soriana.com/pantalla-lg-32-pulg-hd...   $6,490.00   $6,990.00
# 10  https://www.soriana.com/pantalla-lg-75-pulg-4k...  $24,990.00  $41,190.00
# 11  https://www.soriana.com/pantalla-tcl-55-pulg-4...   $9,990.00  $13,299.00
# 12  https://www.soriana.com/pantalla-tcl-50-pulg-4...   $8,990.00  $11,799.00
# 13  https://www.soriana.com/pantalla-samsung-55-pu...  $26,990.00  $36,490.00
# 14  https://www.soriana.com/pantalla-samsung-24-pu...   $3,890.00   $4,790.00
# 15  https://www.soriana.com/consola-xbox-series-s-...         NaN   $8,499.00
# 16  https://www.soriana.com/halo-infinite-xbox-one...         NaN   $1,499.00
# 17  https://www.soriana.com/kit-gamer-dreamgear-dg...         NaN   $1,199.00
# 18  https://www.soriana.com/audifonos-gamer-dreamg...         NaN     $499.00
# 19  https://www.soriana.com/audifonos-gamer-dreamg...         NaN     $499.00
# 20  https://www.soriana.com/halo-infinite-collecto...         NaN   $1,499.00
# 21  https://www.soriana.com/audifonos-estereo-xbox...         NaN   $1,799.00
# 22  https://www.soriana.com/control-inalambrico-xb...         NaN   $1,599.00
# 23  https://www.soriana.com/control-inalambrico-xb...         NaN   $1,599.00
# 24  https://www.soriana.com/audifonos-hyperx-cloud...         NaN     $899.00
# 25  https://www.soriana.com/control-inalambrico-bl...         NaN   $1,619.00
# 26  https://www.soriana.com/control-xbox-inalambri...         NaN   $1,599.00
# 27  https://www.soriana.com/forza-horizon-5-xbox-s...         NaN   $1,499.00
# 28  https://www.soriana.com/control-inalambrico-xb...         NaN   $1,699.00
# 29  https://www.soriana.com/audifonos-dreamgear-gr...         NaN     $799.00
# 30  https://www.soriana.com/laptop-hp-13-bb0501la-...         NaN  $15,499.00
# 31  https://www.soriana.com/laptop-asus-c204ee-cel...   $5,990.00  $10,299.00
# 32  https://www.soriana.com/laptop-asus-bdl-c436fa...   $9,990.00  $21,499.00
# 33  https://www.soriana.com/laptop-hp-28k53lt-abm-...         NaN  $11,999.00
# 34  https://www.soriana.com/laptop-hp-14-dk1010la-...   $6,499.00   $9,299.00
# 35  https://www.soriana.com/laptop-hp-14-dy0005la-...         NaN  $17,799.00
# 36  https://www.soriana.com/laptop-asus-f545fa-i58...         NaN  $18,999.00
# 37  https://www.soriana.com/laptop-hp-15-dy1002la-...         NaN  $14,599.00
# 38  https://www.soriana.com/laptop-asus-p1440fa-fq...         NaN  $19,999.00
# 39  https://www.soriana.com/laptop-hp-omen-15-ek00...         NaN  $64,999.00
# 40  https://www.soriana.com/computadora-ghia-2888-...         NaN   $7,999.00
# 41  https://www.soriana.com/computadora-asus-d540s...   $9,990.00  $14,999.00
# 42  https://www.soriana.com/computadora-asus-d641s...   $9,990.00  $15,299.00
# 43  https://www.soriana.com/mini-pc-ghia-pcghia-21...         NaN   $5,999.00
# 44  https://www.soriana.com/computadora-hp-all-in-...         NaN  $31,499.00

# %%
def precios_floats(datos):

        
    #### eliminamos el signo de pesos de ambas columnas
    
    for i in range(len(datos["precio1"])):
        try:
            datos["precio1"].iloc[i]=datos["precio1"].iloc[i].strip("$")
        except:
            pass
        
    for i in range(len(datos["precio2"])):
        try:
            datos["precio2"].iloc[i]=datos["precio2"].iloc[i].strip("$")
        except:
            pass
        
    
    ### quitamos la separacion de comas para miles
    
    datos["precio1"]=datos["precio1"].replace(",","",regex=True)
    datos["precio2"]=datos["precio2"].replace(",","",regex=True)
    
     
        
    ### convertimos los precios a numericos    
    datos['precio1'] = pd.to_numeric(datos['precio1'], errors='coerce')
    datos['precio2'] = pd.to_numeric(datos['precio2'], errors='coerce')

    
    
    datos.to_excel("df_soriana_limpio.xlsx",index=False)
        
     ### visualizamos los tipos de datos
    print(datos.dtypes)
    return datos

# %%
precios_floats(df_soriana)
# Out:
# fecha            object
# autoservicio     object
# marca            object
# nombre           object
# url              object
# precio1         float64
# precio2         float64
# dtype: object
#        fecha autoservicio       marca  \
# 0   20/01/22      soriana  television
# 1   20/01/22      soriana  television
# 2   20/01/22      soriana  television
# 3   20/01/22      soriana  television
# 4   20/01/22      soriana  television
# 5   20/01/22      soriana  television
# 6   20/01/22      soriana  television
# 7   20/01/22      soriana  television
# 8   20/01/22      soriana  television
# 9   20/01/22      soriana  television
# 10  20/01/22      soriana  television
# 11  20/01/22      soriana  television
# 12  20/01/22      soriana  television
# 13  20/01/22      soriana  television
# 14  20/01/22      soriana  television
# 15  20/01/22      soriana        xbox
# 16  20/01/22      soriana        xbox
# 17  20/01/22      soriana        xbox
# 18  20/01/22      soriana        xbox
# 19  20/01/22      soriana        xbox
# 20  20/01/22      soriana        xbox
# 21  20/01/22      soriana        xbox
# 22  20/01/22      soriana        xbox
# 23  20/01/22      soriana        xbox
# 24  20/01/22      soriana        xbox
# 25  20/01/22      soriana        xbox
# 26  20/01/22      soriana        xbox
# 27  20/01/22      soriana        xbox
# 28  20/01/22      soriana        xbox
# 29  20/01/22      soriana        xbox
# 30  20/01/22      soriana      laptop
# 31  20/01/22      soriana      laptop
# 32  20/01/22      soriana      laptop
# 33  20/01/22      soriana      laptop
# 34  20/01/22      soriana      laptop
# 35  20/01/22      soriana      laptop
# 36  20/01/22      soriana      laptop
# 37  20/01/22      soriana      laptop
# 38  20/01/22      soriana      laptop
# 39  20/01/22      soriana      laptop
# 40  20/01/22      soriana      laptop
# 41  20/01/22      soriana      laptop
# 42  20/01/22      soriana      laptop
# 43  20/01/22      soriana      laptop
# 44  20/01/22      soriana      laptop
#
#                                                nombre  \
# 0   Pantalla Samsung 43 Pulg FHD LED Smart TV LH43...
# 1   Pantalla Samsung 65 Pulg 8K QLED Smart TV QN65...
# 2   Pantalla Samsung 65 Pulg 4K QLED Frame Smart T...
# 3   Pantalla Samsung 55 Pulg 4K QLED Frame Smart T...
# 4   Pantalla Samsung 50 Pulg 4K QLED Frame Smart T...
# 5   Pantalla Samsung 32 Pulg FHD QLED Frame Smart ...
# 6   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 7         Pantalla LG 70 Pulg 4K AI ThinQ 70UN7370PUC
# 8     Pantalla LG 60 Pulg 4K LED AI ThinQ 60UN7300PUA
# 9     Pantalla LG 32 Pulg HD LED AI ThinQ 32LM630BPUB
# 10        Pantalla LG 75 Pulg 4K AI ThinQ 75UP7750PSB
# 11            Pantalla TCL 55 Pulg 4k UHD LED Roku TV
# 12            Pantalla TCL 50 Pulg 4k UHD LED Roku TV
# 13  Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 14             Pantalla Samsung 24 Pulg LT24D315NQ/ZX
# 15             Consola Xbox Series S 512GB SSD Blanca
# 16                             Halo Infinite XBOX One
# 17       Kit Gamer DreamGEAR DGXB1-6631 para Xbox One
# 18  Audífonos Gamer DreamGEAR X-Talk DGXB1-6618 pa...
# 19  Audífonos Gamer DreamGEAR X-Talk DGXB1-6617 pa...
# 20  Halo Infinite Collector's Steelbook Edition XB...
# 21  Audífonos Estéreo Xbox Edición Especial 20 Ani...
# 22          Control Inalámbrico XBOX QAS-00011 Blanco
# 23           Control Inalámbrico XBOX QAT-00011 Negro
# 24           Audífonos Hyperx Cloud Stinger Core Xbox
# 25  Control Inalámbrico Blanco Xbox + Tarjeta Fort...
# 26             Control Xbox Inalámbrico Negro Para Pc
# 27                      Forza Horizon 5 XBOX Series X
# 28            Control Inalámbrico XBOX QAU-00031 Azul
# 29         Audífonos Dreamgear GRX-340 Verde para XB1
# 30             Laptop HP 13-bb0501la Ci3 8GB/256GBSSD
# 31  Laptop Asus C204EE-Cel4G32COs-01 Celeron N4020...
# 32  Laptop Asus BDL C436FA-I38G12 Core i3 8GB RAM ...
# 33  Laptop HP 28K53LT ABM AMD Athlon Silver 4GB RA...
# 34  Laptop HP 14-dk1010la AMD Athlon 4GB RAM 500GB...
# 35  Laptop HP 14 DY0005LA Intel Core i3 8 GB RAM 2...
# 36  Laptop Asus F545FA-I58G1TWH-0 Core i5 8GB RAM ...
# 37  Laptop HP 15-DY1002LA Core i3 8GB RAM 256GB SS...
# 38  Laptop Asus P1440FA-FQ1592R Core i3 8GB RAM 25...
# 39  Laptop HP OMEN 15-EK0007LA Core i7 16GB RAM 51...
# 40  Computadora Ghia 2888 Squadra AIO Celeron N345...
# 41  Computadora Asus D540SA-I34G1TWP-0 Core i3 4GB...
# 42  Computadora Asus D641SC-I38G1TWP-0 Core i3 8GB...
# 43  Mini PC Ghia PCGHIA-2122 Celeron 4GB RAM 64GB ...
# 44  Computadora HP All In One Pavilion 24-K0001LA ...
#
#                                                   url  precio1  precio2
# 0   https://www.soriana.com/pantalla-samsung-43-pu...   8990.0  11490.0
# 1   https://www.soriana.com/pantalla-samsung-65-pu...      NaN  85999.0
# 2   https://www.soriana.com/pantalla-samsung-65-pu...  39490.0  64999.0
# 3   https://www.soriana.com/pantalla-samsung-55-pu...  27990.0  34999.0
# 4   https://www.soriana.com/pantalla-samsung-50-pu...  24590.0  41599.0
# 5   https://www.soriana.com/pantalla-samsung-32-pu...      NaN  19399.0
# 6   https://www.soriana.com/pantalla-samsung-55-pu...  17590.0  30490.0
# 7   https://www.soriana.com/pantalla-lg-70-pulg-4k...  19990.0  38790.0
# 8   https://www.soriana.com/pantalla-lg-60-pulg-4k...  15990.0  25590.0
# 9   https://www.soriana.com/pantalla-lg-32-pulg-hd...   6490.0   6990.0
# 10  https://www.soriana.com/pantalla-lg-75-pulg-4k...  24990.0  41190.0
# 11  https://www.soriana.com/pantalla-tcl-55-pulg-4...   9990.0  13299.0
# 12  https://www.soriana.com/pantalla-tcl-50-pulg-4...   8990.0  11799.0
# 13  https://www.soriana.com/pantalla-samsung-55-pu...  26990.0  36490.0
# 14  https://www.soriana.com/pantalla-samsung-24-pu...   3890.0   4790.0
# 15  https://www.soriana.com/consola-xbox-series-s-...      NaN   8499.0
# 16  https://www.soriana.com/halo-infinite-xbox-one...      NaN   1499.0
# 17  https://www.soriana.com/kit-gamer-dreamgear-dg...      NaN   1199.0
# 18  https://www.soriana.com/audifonos-gamer-dreamg...      NaN    499.0
# 19  https://www.soriana.com/audifonos-gamer-dreamg...      NaN    499.0
# 20  https://www.soriana.com/halo-infinite-collecto...      NaN   1499.0
# 21  https://www.soriana.com/audifonos-estereo-xbox...      NaN   1799.0
# 22  https://www.soriana.com/control-inalambrico-xb...      NaN   1599.0
# 23  https://www.soriana.com/control-inalambrico-xb...      NaN   1599.0
# 24  https://www.soriana.com/audifonos-hyperx-cloud...      NaN    899.0
# 25  https://www.soriana.com/control-inalambrico-bl...      NaN   1619.0
# 26  https://www.soriana.com/control-xbox-inalambri...      NaN   1599.0
# 27  https://www.soriana.com/forza-horizon-5-xbox-s...      NaN   1499.0
# 28  https://www.soriana.com/control-inalambrico-xb...      NaN   1699.0
# 29  https://www.soriana.com/audifonos-dreamgear-gr...      NaN    799.0
# 30  https://www.soriana.com/laptop-hp-13-bb0501la-...      NaN  15499.0
# 31  https://www.soriana.com/laptop-asus-c204ee-cel...   5990.0  10299.0
# 32  https://www.soriana.com/laptop-asus-bdl-c436fa...   9990.0  21499.0
# 33  https://www.soriana.com/laptop-hp-28k53lt-abm-...      NaN  11999.0
# 34  https://www.soriana.com/laptop-hp-14-dk1010la-...   6499.0   9299.0
# 35  https://www.soriana.com/laptop-hp-14-dy0005la-...      NaN  17799.0
# 36  https://www.soriana.com/laptop-asus-f545fa-i58...      NaN  18999.0
# 37  https://www.soriana.com/laptop-hp-15-dy1002la-...      NaN  14599.0
# 38  https://www.soriana.com/laptop-asus-p1440fa-fq...      NaN  19999.0
# 39  https://www.soriana.com/laptop-hp-omen-15-ek00...      NaN  64999.0
# 40  https://www.soriana.com/computadora-ghia-2888-...      NaN   7999.0
# 41  https://www.soriana.com/computadora-asus-d540s...   9990.0  14999.0
# 42  https://www.soriana.com/computadora-asus-d641s...   9990.0  15299.0
# 43  https://www.soriana.com/mini-pc-ghia-pcghia-21...      NaN   5999.0
# 44  https://www.soriana.com/computadora-hp-all-in-...      NaN  31499.0

# %%
df_soriana=pd.read_excel("df_soriana_limpio.xlsx")
df_soriana
# Out:
#        fecha autoservicio       marca  \
# 0   20/01/22      soriana  television
# 1   20/01/22      soriana  television
# 2   20/01/22      soriana  television
# 3   20/01/22      soriana  television
# 4   20/01/22      soriana  television
# 5   20/01/22      soriana  television
# 6   20/01/22      soriana  television
# 7   20/01/22      soriana  television
# 8   20/01/22      soriana  television
# 9   20/01/22      soriana  television
# 10  20/01/22      soriana  television
# 11  20/01/22      soriana  television
# 12  20/01/22      soriana  television
# 13  20/01/22      soriana  television
# 14  20/01/22      soriana  television
# 15  20/01/22      soriana        xbox
# 16  20/01/22      soriana        xbox
# 17  20/01/22      soriana        xbox
# 18  20/01/22      soriana        xbox
# 19  20/01/22      soriana        xbox
# 20  20/01/22      soriana        xbox
# 21  20/01/22      soriana        xbox
# 22  20/01/22      soriana        xbox
# 23  20/01/22      soriana        xbox
# 24  20/01/22      soriana        xbox
# 25  20/01/22      soriana        xbox
# 26  20/01/22      soriana        xbox
# 27  20/01/22      soriana        xbox
# 28  20/01/22      soriana        xbox
# 29  20/01/22      soriana        xbox
# 30  20/01/22      soriana      laptop
# 31  20/01/22      soriana      laptop
# 32  20/01/22      soriana      laptop
# 33  20/01/22      soriana      laptop
# 34  20/01/22      soriana      laptop
# 35  20/01/22      soriana      laptop
# 36  20/01/22      soriana      laptop
# 37  20/01/22      soriana      laptop
# 38  20/01/22      soriana      laptop
# 39  20/01/22      soriana      laptop
# 40  20/01/22      soriana      laptop
# 41  20/01/22      soriana      laptop
# 42  20/01/22      soriana      laptop
# 43  20/01/22      soriana      laptop
# 44  20/01/22      soriana      laptop
#
#                                                nombre  \
# 0   Pantalla Samsung 43 Pulg FHD LED Smart TV LH43...
# 1   Pantalla Samsung 65 Pulg 8K QLED Smart TV QN65...
# 2   Pantalla Samsung 65 Pulg 4K QLED Frame Smart T...
# 3   Pantalla Samsung 55 Pulg 4K QLED Frame Smart T...
# 4   Pantalla Samsung 50 Pulg 4K QLED Frame Smart T...
# 5   Pantalla Samsung 32 Pulg FHD QLED Frame Smart ...
# 6   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 7         Pantalla LG 70 Pulg 4K AI ThinQ 70UN7370PUC
# 8     Pantalla LG 60 Pulg 4K LED AI ThinQ 60UN7300PUA
# 9     Pantalla LG 32 Pulg HD LED AI ThinQ 32LM630BPUB
# 10        Pantalla LG 75 Pulg 4K AI ThinQ 75UP7750PSB
# 11            Pantalla TCL 55 Pulg 4k UHD LED Roku TV
# 12            Pantalla TCL 50 Pulg 4k UHD LED Roku TV
# 13  Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 14             Pantalla Samsung 24 Pulg LT24D315NQ/ZX
# 15             Consola Xbox Series S 512GB SSD Blanca
# 16                             Halo Infinite XBOX One
# 17       Kit Gamer DreamGEAR DGXB1-6631 para Xbox One
# 18  Audífonos Gamer DreamGEAR X-Talk DGXB1-6618 pa...
# 19  Audífonos Gamer DreamGEAR X-Talk DGXB1-6617 pa...
# 20  Halo Infinite Collector's Steelbook Edition XB...
# 21  Audífonos Estéreo Xbox Edición Especial 20 Ani...
# 22          Control Inalámbrico XBOX QAS-00011 Blanco
# 23           Control Inalámbrico XBOX QAT-00011 Negro
# 24           Audífonos Hyperx Cloud Stinger Core Xbox
# 25  Control Inalámbrico Blanco Xbox + Tarjeta Fort...
# 26             Control Xbox Inalámbrico Negro Para Pc
# 27                      Forza Horizon 5 XBOX Series X
# 28            Control Inalámbrico XBOX QAU-00031 Azul
# 29         Audífonos Dreamgear GRX-340 Verde para XB1
# 30             Laptop HP 13-bb0501la Ci3 8GB/256GBSSD
# 31  Laptop Asus C204EE-Cel4G32COs-01 Celeron N4020...
# 32  Laptop Asus BDL C436FA-I38G12 Core i3 8GB RAM ...
# 33  Laptop HP 28K53LT ABM AMD Athlon Silver 4GB RA...
# 34  Laptop HP 14-dk1010la AMD Athlon 4GB RAM 500GB...
# 35  Laptop HP 14 DY0005LA Intel Core i3 8 GB RAM 2...
# 36  Laptop Asus F545FA-I58G1TWH-0 Core i5 8GB RAM ...
# 37  Laptop HP 15-DY1002LA Core i3 8GB RAM 256GB SS...
# 38  Laptop Asus P1440FA-FQ1592R Core i3 8GB RAM 25...
# 39  Laptop HP OMEN 15-EK0007LA Core i7 16GB RAM 51...
# 40  Computadora Ghia 2888 Squadra AIO Celeron N345...
# 41  Computadora Asus D540SA-I34G1TWP-0 Core i3 4GB...
# 42  Computadora Asus D641SC-I38G1TWP-0 Core i3 8GB...
# 43  Mini PC Ghia PCGHIA-2122 Celeron 4GB RAM 64GB ...
# 44  Computadora HP All In One Pavilion 24-K0001LA ...
#
#                                                   url  precio1  precio2
# 0   https://www.soriana.com/pantalla-samsung-43-pu...   8990.0    11490
# 1   https://www.soriana.com/pantalla-samsung-65-pu...      NaN    85999
# 2   https://www.soriana.com/pantalla-samsung-65-pu...  39490.0    64999
# 3   https://www.soriana.com/pantalla-samsung-55-pu...  27990.0    34999
# 4   https://www.soriana.com/pantalla-samsung-50-pu...  24590.0    41599
# 5   https://www.soriana.com/pantalla-samsung-32-pu...      NaN    19399
# 6   https://www.soriana.com/pantalla-samsung-55-pu...  17590.0    30490
# 7   https://www.soriana.com/pantalla-lg-70-pulg-4k...  19990.0    38790
# 8   https://www.soriana.com/pantalla-lg-60-pulg-4k...  15990.0    25590
# 9   https://www.soriana.com/pantalla-lg-32-pulg-hd...   6490.0     6990
# 10  https://www.soriana.com/pantalla-lg-75-pulg-4k...  24990.0    41190
# 11  https://www.soriana.com/pantalla-tcl-55-pulg-4...   9990.0    13299
# 12  https://www.soriana.com/pantalla-tcl-50-pulg-4...   8990.0    11799
# 13  https://www.soriana.com/pantalla-samsung-55-pu...  26990.0    36490
# 14  https://www.soriana.com/pantalla-samsung-24-pu...   3890.0     4790
# 15  https://www.soriana.com/consola-xbox-series-s-...      NaN     8499
# 16  https://www.soriana.com/halo-infinite-xbox-one...      NaN     1499
# 17  https://www.soriana.com/kit-gamer-dreamgear-dg...      NaN     1199
# 18  https://www.soriana.com/audifonos-gamer-dreamg...      NaN      499
# 19  https://www.soriana.com/audifonos-gamer-dreamg...      NaN      499
# 20  https://www.soriana.com/halo-infinite-collecto...      NaN     1499
# 21  https://www.soriana.com/audifonos-estereo-xbox...      NaN     1799
# 22  https://www.soriana.com/control-inalambrico-xb...      NaN     1599
# 23  https://www.soriana.com/control-inalambrico-xb...      NaN     1599
# 24  https://www.soriana.com/audifonos-hyperx-cloud...      NaN      899
# 25  https://www.soriana.com/control-inalambrico-bl...      NaN     1619
# 26  https://www.soriana.com/control-xbox-inalambri...      NaN     1599
# 27  https://www.soriana.com/forza-horizon-5-xbox-s...      NaN     1499
# 28  https://www.soriana.com/control-inalambrico-xb...      NaN     1699
# 29  https://www.soriana.com/audifonos-dreamgear-gr...      NaN      799
# 30  https://www.soriana.com/laptop-hp-13-bb0501la-...      NaN    15499
# 31  https://www.soriana.com/laptop-asus-c204ee-cel...   5990.0    10299
# 32  https://www.soriana.com/laptop-asus-bdl-c436fa...   9990.0    21499
# 33  https://www.soriana.com/laptop-hp-28k53lt-abm-...      NaN    11999
# 34  https://www.soriana.com/laptop-hp-14-dk1010la-...   6499.0     9299
# 35  https://www.soriana.com/laptop-hp-14-dy0005la-...      NaN    17799
# 36  https://www.soriana.com/laptop-asus-f545fa-i58...      NaN    18999
# 37  https://www.soriana.com/laptop-hp-15-dy1002la-...      NaN    14599
# 38  https://www.soriana.com/laptop-asus-p1440fa-fq...      NaN    19999
# 39  https://www.soriana.com/laptop-hp-omen-15-ek00...      NaN    64999
# 40  https://www.soriana.com/computadora-ghia-2888-...      NaN     7999
# 41  https://www.soriana.com/computadora-asus-d540s...   9990.0    14999
# 42  https://www.soriana.com/computadora-asus-d641s...   9990.0    15299
# 43  https://www.soriana.com/mini-pc-ghia-pcghia-21...      NaN     5999
# 44  https://www.soriana.com/computadora-hp-all-in-...      NaN    31499

# %%
ps.sqldf("select  * from df_soriana where (marca= 'xbox') limit 5")
# Out:
#       fecha autoservicio marca  \
# 0  20/01/22      soriana  xbox
# 1  20/01/22      soriana  xbox
# 2  20/01/22      soriana  xbox
# 3  20/01/22      soriana  xbox
# 4  20/01/22      soriana  xbox
#
#                                               nombre  \
# 0             Consola Xbox Series S 512GB SSD Blanca
# 1                             Halo Infinite XBOX One
# 2       Kit Gamer DreamGEAR DGXB1-6631 para Xbox One
# 3  Audífonos Gamer DreamGEAR X-Talk DGXB1-6618 pa...
# 4  Audífonos Gamer DreamGEAR X-Talk DGXB1-6617 pa...
#
#                                                  url precio1  precio2
# 0  https://www.soriana.com/consola-xbox-series-s-...    None     8499
# 1  https://www.soriana.com/halo-infinite-xbox-one...    None     1499
# 2  https://www.soriana.com/kit-gamer-dreamgear-dg...    None     1199
# 3  https://www.soriana.com/audifonos-gamer-dreamg...    None      499
# 4  https://www.soriana.com/audifonos-gamer-dreamg...    None      499

# %%
ps.sqldf("select count(*) from df_soriana where (marca= 'television') ")
# Out:
#    count(*)
# 0        15

# %%
ps.sqldf("select marca,avg(precio2) as preciopromedio from df_soriana group by marca ")
# Out:
#         marca  preciopromedio
# 0      laptop         18719.0
# 1  television         31194.2
# 2        xbox          1787.0

# %%
ps.sqldf("select *  from df_soriana where precio1 is not null ")
# Out:
#        fecha autoservicio       marca  \
# 0   20/01/22      soriana  television
# 1   20/01/22      soriana  television
# 2   20/01/22      soriana  television
# 3   20/01/22      soriana  television
# 4   20/01/22      soriana  television
# 5   20/01/22      soriana  television
# 6   20/01/22      soriana  television
# 7   20/01/22      soriana  television
# 8   20/01/22      soriana  television
# 9   20/01/22      soriana  television
# 10  20/01/22      soriana  television
# 11  20/01/22      soriana  television
# 12  20/01/22      soriana  television
# 13  20/01/22      soriana      laptop
# 14  20/01/22      soriana      laptop
# 15  20/01/22      soriana      laptop
# 16  20/01/22      soriana      laptop
# 17  20/01/22      soriana      laptop
#
#                                                nombre  \
# 0   Pantalla Samsung 43 Pulg FHD LED Smart TV LH43...
# 1   Pantalla Samsung 65 Pulg 4K QLED Frame Smart T...
# 2   Pantalla Samsung 55 Pulg 4K QLED Frame Smart T...
# 3   Pantalla Samsung 50 Pulg 4K QLED Frame Smart T...
# 4   Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 5         Pantalla LG 70 Pulg 4K AI ThinQ 70UN7370PUC
# 6     Pantalla LG 60 Pulg 4K LED AI ThinQ 60UN7300PUA
# 7     Pantalla LG 32 Pulg HD LED AI ThinQ 32LM630BPUB
# 8         Pantalla LG 75 Pulg 4K AI ThinQ 75UP7750PSB
# 9             Pantalla TCL 55 Pulg 4k UHD LED Roku TV
# 10            Pantalla TCL 50 Pulg 4k UHD LED Roku TV
# 11  Pantalla Samsung 55 Pulg 4K QLED Smart TV QN55...
# 12             Pantalla Samsung 24 Pulg LT24D315NQ/ZX
# 13  Laptop Asus C204EE-Cel4G32COs-01 Celeron N4020...
# 14  Laptop Asus BDL C436FA-I38G12 Core i3 8GB RAM ...
# 15  Laptop HP 14-dk1010la AMD Athlon 4GB RAM 500GB...
# 16  Computadora Asus D540SA-I34G1TWP-0 Core i3 4GB...
# 17  Computadora Asus D641SC-I38G1TWP-0 Core i3 8GB...
#
#                                                   url  precio1  precio2
# 0   https://www.soriana.com/pantalla-samsung-43-pu...   8990.0    11490
# 1   https://www.soriana.com/pantalla-samsung-65-pu...  39490.0    64999
# 2   https://www.soriana.com/pantalla-samsung-55-pu...  27990.0    34999
# 3   https://www.soriana.com/pantalla-samsung-50-pu...  24590.0    41599
# 4   https://www.soriana.com/pantalla-samsung-55-pu...  17590.0    30490
# 5   https://www.soriana.com/pantalla-lg-70-pulg-4k...  19990.0    38790
# 6   https://www.soriana.com/pantalla-lg-60-pulg-4k...  15990.0    25590
# 7   https://www.soriana.com/pantalla-lg-32-pulg-hd...   6490.0     6990
# 8   https://www.soriana.com/pantalla-lg-75-pulg-4k...  24990.0    41190
# 9   https://www.soriana.com/pantalla-tcl-55-pulg-4...   9990.0    13299
# 10  https://www.soriana.com/pantalla-tcl-50-pulg-4...   8990.0    11799
# 11  https://www.soriana.com/pantalla-samsung-55-pu...  26990.0    36490
# 12  https://www.soriana.com/pantalla-samsung-24-pu...   3890.0     4790
# 13  https://www.soriana.com/laptop-asus-c204ee-cel...   5990.0    10299
# 14  https://www.soriana.com/laptop-asus-bdl-c436fa...   9990.0    21499
# 15  https://www.soriana.com/laptop-hp-14-dk1010la-...   6499.0     9299
# 16  https://www.soriana.com/computadora-asus-d540s...   9990.0    14999
# 17  https://www.soriana.com/computadora-asus-d641s...   9990.0    15299

# %%
ps.sqldf("select *  from df_soriana where precio1 <10000 or precio2<10000 ")
# Out:
#        fecha autoservicio       marca  \
# 0   20/01/22      soriana  television
# 1   20/01/22      soriana  television
# 2   20/01/22      soriana  television
# 3   20/01/22      soriana  television
# 4   20/01/22      soriana  television
# 5   20/01/22      soriana        xbox
# 6   20/01/22      soriana        xbox
# 7   20/01/22      soriana        xbox
# 8   20/01/22      soriana        xbox
# 9   20/01/22      soriana        xbox
# 10  20/01/22      soriana        xbox
# 11  20/01/22      soriana        xbox
# 12  20/01/22      soriana        xbox
# 13  20/01/22      soriana        xbox
# 14  20/01/22      soriana        xbox
# 15  20/01/22      soriana        xbox
# 16  20/01/22      soriana        xbox
# 17  20/01/22      soriana        xbox
# 18  20/01/22      soriana        xbox
# 19  20/01/22      soriana        xbox
# 20  20/01/22      soriana      laptop
# 21  20/01/22      soriana      laptop
# 22  20/01/22      soriana      laptop
# 23  20/01/22      soriana      laptop
# 24  20/01/22      soriana      laptop
# 25  20/01/22      soriana      laptop
# 26  20/01/22      soriana      laptop
#
#                                                nombre  \
# 0   Pantalla Samsung 43 Pulg FHD LED Smart TV LH43...
# 1     Pantalla LG 32 Pulg HD LED AI ThinQ 32LM630BPUB
# 2             Pantalla TCL 55 Pulg 4k UHD LED Roku TV
# 3             Pantalla TCL 50 Pulg 4k UHD LED Roku TV
# 4              Pantalla Samsung 24 Pulg LT24D315NQ/ZX
# 5              Consola Xbox Series S 512GB SSD Blanca
# 6                              Halo Infinite XBOX One
# 7        Kit Gamer DreamGEAR DGXB1-6631 para Xbox One
# 8   Audífonos Gamer DreamGEAR X-Talk DGXB1-6618 pa...
# 9   Audífonos Gamer DreamGEAR X-Talk DGXB1-6617 pa...
# 10  Halo Infinite Collector's Steelbook Edition XB...
# 11  Audífonos Estéreo Xbox Edición Especial 20 Ani...
# 12          Control Inalámbrico XBOX QAS-00011 Blanco
# 13           Control Inalámbrico XBOX QAT-00011 Negro
# 14           Audífonos Hyperx Cloud Stinger Core Xbox
# 15  Control Inalámbrico Blanco Xbox + Tarjeta Fort...
# 16             Control Xbox Inalámbrico Negro Para Pc
# 17                      Forza Horizon 5 XBOX Series X
# 18            Control Inalámbrico XBOX QAU-00031 Azul
# 19         Audífonos Dreamgear GRX-340 Verde para XB1
# 20  Laptop Asus C204EE-Cel4G32COs-01 Celeron N4020...
# 21  Laptop Asus BDL C436FA-I38G12 Core i3 8GB RAM ...
# 22  Laptop HP 14-dk1010la AMD Athlon 4GB RAM 500GB...
# 23  Computadora Ghia 2888 Squadra AIO Celeron N345...
# 24  Computadora Asus D540SA-I34G1TWP-0 Core i3 4GB...
# 25  Computadora Asus D641SC-I38G1TWP-0 Core i3 8GB...
# 26  Mini PC Ghia PCGHIA-2122 Celeron 4GB RAM 64GB ...
#
#                                                   url  precio1  precio2
# 0   https://www.soriana.com/pantalla-samsung-43-pu...   8990.0    11490
# 1   https://www.soriana.com/pantalla-lg-32-pulg-hd...   6490.0     6990
# 2   https://www.soriana.com/pantalla-tcl-55-pulg-4...   9990.0    13299
# 3   https://www.soriana.com/pantalla-tcl-50-pulg-4...   8990.0    11799
# 4   https://www.soriana.com/pantalla-samsung-24-pu...   3890.0     4790
# 5   https://www.soriana.com/consola-xbox-series-s-...      NaN     8499
# 6   https://www.soriana.com/halo-infinite-xbox-one...      NaN     1499
# 7   https://www.soriana.com/kit-gamer-dreamgear-dg...      NaN     1199
# 8   https://www.soriana.com/audifonos-gamer-dreamg...      NaN      499
# 9   https://www.soriana.com/audifonos-gamer-dreamg...      NaN      499
# 10  https://www.soriana.com/halo-infinite-collecto...      NaN     1499
# 11  https://www.soriana.com/audifonos-estereo-xbox...      NaN     1799
# 12  https://www.soriana.com/control-inalambrico-xb...      NaN     1599
# 13  https://www.soriana.com/control-inalambrico-xb...      NaN     1599
# 14  https://www.soriana.com/audifonos-hyperx-cloud...      NaN      899
# 15  https://www.soriana.com/control-inalambrico-bl...      NaN     1619
# 16  https://www.soriana.com/control-xbox-inalambri...      NaN     1599
# 17  https://www.soriana.com/forza-horizon-5-xbox-s...      NaN     1499
# 18  https://www.soriana.com/control-inalambrico-xb...      NaN     1699
# 19  https://www.soriana.com/audifonos-dreamgear-gr...      NaN      799
# 20  https://www.soriana.com/laptop-asus-c204ee-cel...   5990.0    10299
# 21  https://www.soriana.com/laptop-asus-bdl-c436fa...   9990.0    21499
# 22  https://www.soriana.com/laptop-hp-14-dk1010la-...   6499.0     9299
# 23  https://www.soriana.com/computadora-ghia-2888-...      NaN     7999
# 24  https://www.soriana.com/computadora-asus-d540s...   9990.0    14999
# 25  https://www.soriana.com/computadora-asus-d641s...   9990.0    15299
# 26  https://www.soriana.com/mini-pc-ghia-pcghia-21...      NaN     5999
